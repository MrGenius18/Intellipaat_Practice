# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import the Data

# %%
data = pd.read_csv('customer_churn.csv')

# %% [markdown]
# # Analyze the data

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# ### Extract the 5th column from this dataset and
# * store it in 'column_5'
# ### Extract the 15th column from this dataset and
# * store it in 'column_15'
# ### extract 333 random records from dataset,
# * store them in data_333

# %%
column_5 = data.iloc[:,4]
column_15 = data.iloc[:,14]
data_333 = data.sample(333)
data_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2170  8220-OCUFY  Female              0      No         No      21
# 2687  5213-TWWJU    Male              0      No         No      28
# 2774  9375-MHRRS    Male              0      No         No       6
# 3608  3208-YPIOE    Male              0      No         No      39
# 1580  7108-DGVUU  Female              1     Yes         No      21
# ...          ...     ...            ...     ...        ...     ...
# 2248  9554-DFKIC    Male              0     Yes        Yes      30
# 1164  4782-OSFXZ  Female              1     Yes         No      71
# 4934  2272-WUSPA  Female              0     Yes         No      72
# 3071  9224-VTYID    Male              0     Yes        Yes      47
# 926   7074-IEVOJ  Female              1      No         No       3
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2170          Yes            No             DSL            Yes  ...
# ...

# %% [markdown]
# ### Extract all the male senior citizens whose payment method is electronic check and
# * store them in 'senior_male_electronic'

# %%
senior_male_electronic = data[(data['gender']=='Male') & (data['SeniorCitizen']==1) & (data['PaymentMethod']=='Electronic check')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### Extract all those customers whose tenure is greater than 70 months or their monthly charges is more than 100.
# * Store the result in customer_total_tenure

# %%
customer_total_tenure = data[(data['tenure'] > 70) | (data['MonthlyCharges'] > 100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %% [markdown]
# ### Extract all the customers whose contract is of two years, payment method is mailed check and the value of churn is 'Yes'.
# * Store it in 'two_mail_yes'

# %%
two_mail_yes = data[(data['Contract']=='Two year') & (data['PaymentMethod']=='Mailed check') & (data['Churn'] == 'Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %% [markdown]
# ### Churn column ->
# * How many yes are there and how many no are there.

# %%
data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# # Data Visulization

# %% [markdown]
# ### Bar plot for InternetService column
# * x-label -> 'Categories of Internet Service'
# * y-label -> Count of Categories
# * color -> Orange

# %%
sns.countplot(data=data, x='InternetService', color='Orange')
plt.xlabel('Categories of Internet Services')
plt.ylabel('Count of Categories')
plt.show()

# %% [markdown]
# ### Build a histogram for your tenure column
# * number of bins = 30
# * color of the bins = 'green'
# * Title -> Distribution of Tenure

# %%
sns.histplot(data=data, x='tenure', bins=30, color='green')
plt.title('Distribution of Tenure')
plt.show()

# %% [markdown]
# ### Scatter Plot
# * Between two columns MonthlyCharges, tenure

# %%
sns.scatterplot(data=data, x='MonthlyCharges', y='tenure', color='Brown')
plt.show()

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ### Lable Encoding
# * Target object value --> Numerical value (data['Churn'])

# %%
data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['Churn'] = le.fit_transform(data['Churn'])
data['Churn'].value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %% [markdown]
# # Train Test Split Our Data

# %% [markdown]
# ### Predict the churn on the basis of monthly charges

# %%
X = data[['MonthlyCharges']] # if not work so use 2d array
Y = data['Churn'] # Target Var

X_dt = data[['tenure']] # In the using Decision Tree
X_rf = data[['tenure', 'MonthlyCharges']] # In the using RAndom Forest

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.35, random_state=1)

# %% [markdown]
# # Logistic Regression Model

# %% [markdown]
# ### Crete a Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logistic_reg = LogisticRegression()
Logistic_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Predict the Model

# %%
y_train_pradict = Logistic_reg.predict(x_train)
y_test_pradict = Logistic_reg.predict(x_test)

# %% [markdown]
# ### Check the Accurancy

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_test_pradict)
# Out:
# 0.7461476074614761

# %%
accuracy_score(y_train, y_train_pradict)
# Out:
# 0.7284247323574393

# %% [markdown]
# # Decision Tree Model

# %%
xdt_train, xdt_test, ydt_train, ydt_test = train_test_split(X_dt, Y, train_size=0.8, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier()
decision_tree = decision_tree.fit(xdt_train, ydt_train)

# %%
ydt_train_pred = decision_tree.predict(xdt_train)
ydt_test_pred = decision_tree.predict(xdt_test)

# %%
accuracy_score(ydt_train, ydt_train_pred)
# Out:
# 0.7564785232516862

# %%
accuracy_score(ydt_test, ydt_test_pred)
# Out:
# 0.7572746628814763

# %% [markdown]
# # Random Forest Model

# %%
xrf_train, xrf_test, yrf_train, yrf_test = train_test_split(X_rf, Y, train_size=0.7, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

Random_Forest = RandomForestClassifier()
Random_Forest = Random_Forest.fit(xrf_train, yrf_train)

# %%
yrf_train_pred = Random_Forest.predict(xrf_train)
yrf_test_pred = Random_Forest.predict(xrf_test)

# %%
accuracy_score(yrf_train, yrf_train_pred)
# Out:
# 0.9809330628803246

# %%
accuracy_score(yrf_test, yrf_test_pred)
# Out:
# 0.7501183151916706
